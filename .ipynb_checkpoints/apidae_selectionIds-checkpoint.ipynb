# %%
import requests
import json
import DB_func as DBdf
import apidae_extraction as apex

project_ID = '4364'
api_KEY = 'ALrtqQmv'

list_selectionId = ["86750"] # Example "86749",,"86751","86752","86753","86960","86961","86962","86963"

GPS_coordinates =["45.188529","5.724524"]
radius = 30000      # 30km

def retrive_data_by_selectionId(project_ID,api_KEY,list_selectionId):
    import pandas as pd
    result_df = pd.DataFrame(columns = ['lieu_event','names','types','longitude','latitude',
                                'adresse1','adresse2','code_postal','ville','description_teaser',
                                'description_','images','publics','categories','accessibilité',
                                'payant','plus_d_infos_et_horaires','date_début','date_fin']) 
    
    url = 'http://api.apidae-tourisme.com/api/v002/recherche/list-objets-touristiques?query={'
    url += '"projetId":"'+project_ID+'",'
    url += '"apiKey":"'+api_KEY+'",'
    first = True
    for value in list_selectionId :
        if first :
            url += '"selectionIds":["'+value+'"'
            first = False
        else :
            url += ',"'+value+'"'
    url += ']}'
    #print(url)
    # retrieve_data_by_id(project_ID,api_KEY,select_id)
    req = requests.get(url)
    df = pd.json_normalize(req.json(),'objetsTouristiques', errors='ignore')
    
    for index, row in df.iterrows():
        #print(row['id'])#my first DataFrame
        ligne_df=apex.retrieve_data_by_id(project_ID,api_KEY,str(row['id']))
        #df = apex.append(df(index=[0]),ignore_index=True)
        result_df = result_df.append(ligne_df)
    return result_df

Id_selection = retrive_data_by_selectionId(project_ID,api_KEY,list_selectionId)
Id_selection
# Out:
#   lieu_event                                           names         types  \
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole  RESTAURATION
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
# 0       Lieu  Office de Tourisme de Grenoble-Alpes Métropole    EQUIPEMENT
#
#    longitude   latitude                           adresse1 adresse2  \
# 0   5.679989  45.237448              1 rue Casimir Brenier     None
# 0   5.769736  45.203077             29 Boulevard des Alpes     None
# 0   5.689422  45.170782              18 rue de la Tuilerie     None
# 0   5.728974  45.190587            10 Rue de la République     None
# 0   5.724817  45.173218               90 Rue de Stalingrad     None
# 0   5.731127  45.185500  12, Boulevard du Maréchal Lyautey     None
# 0   5.741948  45.179590              1 Rue de la Bajatière     None
# 0   5.727399  45.192324                  1 Place de Gordes     None
# 0   5.729593  45.193006                1, place aux herbes     None
# 0   5.689165  45.120235                 2, rue de l'Europe     None
# 0   5.722431  45.190771               17 rue Docteur Mazet     None
# 0   5.731324  45.194464                 5, place Lavalette     None
# 0   5.720151  45.190701                7 cours Jean Jaurès     None
# 0   5.715448  45.191748              6, rue Emile Gueymard     None
# 0   5.710052  45.195744                3 parvis Louis Néel     None
# 0   5.717319  45.183503               92 cours Jean Jaurès     None
# 0   5.656588  45.245715           8 avenue de la louisiane     None
# 0   5.717581  45.151050           56, avenue du 8 mai 1945     None
# 0   5.701861  45.138613                  83 cours St André     None
# 0   5.719248  45.195466                  28, route de Lyon     None
#
#   code_postal               ville  \
# 0       38120        Saint-Égrève
# 0       38240              Meylan
# 0       38170   Seyssinet-Pariset
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38640               Claix
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38000            Grenoble
# 0       38120  Fontanil-Cornillon
# 0       38130          Échirolles
# 0       38800    Le Pont-de-Claix
# 0       38000            Grenoble
#
#                                   description_teaser  \
# 0  La bibliothèque Maison de Barnave de Saint Egr...
# 0  Bureaux privatifs accès 24h/24 7j/7 à Meylan p...
# 0  Bureaux privatifs accès 24h/24 7j/7 à Seyssine...
# 0  Située en plein centre ville, la bibliothèque ...
# 0  La bibliothèque adulte et jeunesse vous accuei...
# 0  Véritable patrimoine culturel dédié à l’écrit....
# 0  Bibliothèque tout public, elle dispose de livr...
# 0  Entièrement dédiée aux enfants et ados, cette ...
# 0  Ce haut-lieu de la cuisine traditionnelle gren...
# 0  Venez savourer les menus du terroir et profite...
# 0  Le Jardin d'Asie vous propose de découvrir ses...
# 0  Le restaurant du musée de Grenoble. Venez déco...
# 0  Dans une ambiance conviviale et chaleureuse, c...
# 0  La salle à Manger est  un restaurant école cré...
# 0  Avec 1300m2 d'espaces dédiés aux événements et...
# 0  Lieu qui fait partie du patrimoine culinaire g...
# 0  En restaurant et son hôtel pas comme les autre...
# 0  Cuisine de tradition, simple et généreuse auto...
# 0  Piscine avec 3 bassins, rivière à contre coura...
# 0  Massages professionnels relaxants, énergisants...
#
#                                         description_  \
# 0  La bibliothèque Maison de Barnave de Saint Egr...
# 0  Bureaux privatifs accès 24h/24 7j/7 à Meylan p...
# 0  Bureaux privatifs accès 24h/24 7j/7 à Seyssine...
# 0  Située en plein centre ville, la bibliothèque ...
# 0  La bibliothèque adulte et jeunesse vous accuei...
# 0  Véritable patrimoine culturel dédié à l’écrit....
# 0  Bibliothèque tout public, elle dispose de livr...
# 0  Entièrement dédiée aux enfants et ados, cette ...
# 0  Ce haut-lieu de la cuisine traditionnelle gren...
# 0  Venez savourer les menus du terroir et profite...
# 0  Le Jardin d'Asie vous propose de découvrir ses...
# 0  Le restaurant du musée de Grenoble. Venez déco...
# 0  Dans une ambiance conviviale et chaleureuse, c...
# 0  La salle à Manger est  un restaurant école cré...
# 0  Avec 1300m2 d'espaces dédiés aux événements et...
# 0  Lieu qui fait partie du patrimoine culinaire g...
# 0  En restaurant et son hôtel pas comme les autre...
# 0  Cuisine de tradition, simple et généreuse auto...
# 0  Piscine avec 3 bassins, rivière à contre coura...
# 0  Massages professionnels relaxants, énergisants...
#
#                                               images  publics categories  \
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
#
#   accessibilité payant          plus_d_infos_et_horaires date_début date_fin
# 0       no info   True  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info   True  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
# 0       no info  False  http://www.grenoble-tourisme.com       None     None
