# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
project_ID = '4364'
api_KEY = 'ALrtqQmv'
select_id = "86749"     # Example

def retrieve_data_by_id(project_ID,api_KEY,select_id):
    
    result_df = pd.DataFrame(columns = ['id_apidae','Lieu_Event','Names','Types','Longitude','Latitude',
                                'Adresse1','Adresse2','Code_postal','Ville','Description_Teaser',
                                'Description_','Images','Publics','Categories','Accessibilité',
                                'Payant','Plus_d_infos_et_horaires','Date_début','Date_fin']) 
    
    url = 'http://api.apidae-tourisme.com/api/v002/objet-touristique/get-by-id/' + select_id + '?'
    url += "responseFields=id,nom,informations,presentation.descriptifCourt,@all"
    url += '&apiKey='+api_KEY
    url += '&projetId='+project_ID

    re = requests.get(url)
    req = re.json()
    
    dict_for_id = {}
    dict_for_id['id_apidae'] = req['id']
    dict_for_id['Lieu_Event'] = 'Lieu'
    dict_for_id['Names'] = req['gestion']['membreProprietaire']['nom']
    dict_for_id['Types'] = req['type']
    dict_for_id['Longitude'] = req['localisation']['geolocalisation']['geoJson']['coordinates'][0]
    dict_for_id['Latitude'] = req['localisation']['geolocalisation']['geoJson']['coordinates'][1]
    dict_for_id['Adresse1'] = req['localisation']['adresse']['adresse1']
    dict_for_id['Adresse2'] = req['localisation']['adresse']['adresse2']
    dict_for_id['Code_postal'] = req['localisation']['adresse']['codePostal']
    dict_for_id['Ville'] = req['localisation']['adresse']['commune']['nom']
    
    dict_for_id['Description_Teaser'] = req['presentation']['descriptifCourt']['libelleFr']
    dict_for_id['Description_'] = req['presentation']['descriptifCourt']['libelleFr']
    
    dict_for_id['Images'] = req['illustrations'][0]['traductionFichiers'][0]['url']
    dict_for_id['Publics'] = 'no info'
    dict_for_id['Categories'] = 'no info'
    dict_for_id['Accessibilité'] = 'no info'
    dict_for_id['Payant'] = req['descriptionTarif']['gratuit']
    dict_for_id['Plus_d_infos_et_horaires'] = req['gestion']['membreProprietaire']['siteWeb']
    dict_for_id['Date_début'] = req['ouverture']['periodesOuvertures'][0]['dateDebut']
    dict_for_id['Date_fin'] = req['ouverture']['periodesOuvertures'][0]['dateFin']
    #print(dict_for_id)
    result_df = result_df.append(dict_for_id,ignore_index=True)
    
    return result_df

#print(retrive_data_by_selectionId(project_ID,api_KEY,selectionId))
datafra = retrieve_data_by_id(project_ID,api_KEY,select_id)
datafra
# Out:
#   id_apidae Lieu_Event                     Names                Types  \
# 0     86749       Lieu  Vallée de Bozel Tourisme  HEBERGEMENT_LOCATIF
#
#    Longitude   Latitude    Adresse1           Adresse2 Code_postal   Ville  \
# 0    6.68429  45.442534  Les Voûtes  34 Rue des Tovets       73350  Planay
#
#                                   Description_Teaser  \
# 0  Appartement situé dans un chalet, à 5min de Bo...
#
#                                         Description_  \
# 0  Appartement situé dans un chalet, à 5min de Bo...
#
#                                               Images  Publics Categories  \
# 0  http://static.apidae-tourisme.com/filestore/ob...  no info    no info
#
#   Accessibilité Payant Plus_d_infos_et_horaires  Date_début    Date_fin
# 0       no info  False  http://www.ot-bozel.com  2013-01-01  2013-12-31

# %%
### project_ID = '4364'
api_KEY = 'ALrtqQmv'
select_id = "86749"     # Example

def retrive_data_by_id(project_ID,api_KEY,select_id):
    
    result_df = pd.DataFrame(columns = ['id','id_apidae','Lieu_Event','Name_','Type_','Latitude','Longitude',
                                'Adresse1','Adresse2','Code_postal','Ville','Description_Teaser',
                                'Description_','Image_','Publics','Categories','Accessibilité',
                                'Payant','Plus_d_infos_et_horaires','Date_début','Date_fin']) 
    
    url = 'http://api.apidae-tourisme.com/api/v002/objet-touristique/get-by-id/' + select_id + '?'
    url += "responseFields=id,nom,informations,presentation.descriptifCourt,@all"
    url += '&apiKey='+api_KEY
    url += '&projetId='+project_ID

    req = requests.get(url)
 
    return req.json()

#print(retrive_data_by_selectionId(project_ID,api_KEY,selectionId))
datafra = retrive_data_by_id(project_ID,api_KEY,select_id)
datafra
# Out:
# {'type': 'HEBERGEMENT_LOCATIF',
#  'id': 86749,
#  'nom': {'libelleFr': 'Hosana Sylviane'},
#  'identifier': 'sitraHLO713841',
#  'state': 'PUBLISHED',
#  'gestion': {'dateCreation': '2011-10-12T13:59:37.047+0000',
#   'dateModification': '2019-11-12T10:20:59.438+0000',
#   'dateExportModification': '2019-11-12T10:21:00.934+0000',
#   'membreProprietaire': {'type': {'elementReferenceType': 'MembreSitraType',
#     'id': 233,
#     'libelleFr': 'Contributeur Généraliste',
#     'ordre': 1},
#    'nom': 'Vallée de Bozel Tourisme',
#    'dateCreation': '2011-03-07T14:13:30.070+0000',
#    'dateModification': '2020-04-07T12:17:28.442+0000',
#    'id': 430,
#    'siteWeb': 'http://www.ot-bozel.com'},
#   'signalerUnProblemeMails': ['nadia.chevassu@valleedebozel.com']},
#  'informations': {'moyensCommunication': [{'identifiant': 17383348,
#     'type': {'elementReferenceType': 'MoyenCommunicationType',
#      'id': 205,
#      'libelleFr': 'Site web (URL)',
#      'ordre': 3},
# ...

# %%
{% extends "layout.html" %}
{% block bootstrap_2 %}
<section id="app" class="hero is-fullheight">
    <div class="hero-body">
      <div class="container">
        <div class="columns">
          <div class="column is-half is-offset-one-quarter" style="width: 55%;">
            <p class="title"><img src="/static/image/logo_cooltogo.svg" alt="logo" style="width:40px;">
              Edit informations
            </p>
            <div>
            <form action="/edit_data_valid" method="post">
                <!-- ------------------ id Apidae ----------------------- -->
                <div class="field">
                    <label class="label">id_apidae</label>
                        <input
                        name="id_apidae"
                        value="{{id_apidae}}"
                        class="input"
                        type="text"
                        maxlength="40"
                        style="color: #3f3d3d;"
                        readonly>
                </div>
                <!-- ---------- Choose a lieu or an event ----------- -->
                <div class="field">
                    <label class="label">lieu_event</label>
                        <span class="select">
                            <select name="lieu_event" required>
                            {% if lieu_event=="Lieu" %}
                                <option selected>Lieu</option>
                                <option>Event</option>
                            {% elif lieu_event=="Event" %}
                                <option>Lieu</option>
                                <option selected>Event</option>
                            {% else %}
                                <option selected></option>
                                <option>Lieu</option>
                                <option>Event</option>
                            {% endif %}
                            </select>
                        </span>
                </div>
                <!-- --------------- name of responsible --------------- -->
                <div class="field">
                    <label class="label">name</label>
                        <input
                        name="name"
                        value="{{name}}"
                        class="input"
                        type="text"
                        maxlength="50"
                        style="color: #3f3d3d;"
                        required>
                </div>
                <!-- ----------------- Niveau Fracheur ------------------- -->
                <div class="field">
                    <label class="label">Niveau Fraicheur</label>
                        <input
                        name="niveau_fracheur"
                        class="input"
                        type="text"
                        maxlength="80"
                        style="color: #3f3d3d;"
                        required>
                </div>
                <!-- ------------------ Choose a type ------------------- -->
                <div class="field">
                    <label class="label">type</label>
                        <span class="select">
                            <select name="categories">
                                {% if categories=="Être à l’ombre en nature" %}
                                <option selected>Être à l’ombre en nature</option>
                                <option>Être au contact de l'eau</option>
                                <option>Ressources solidaires</option>
                                <option>Se divertir en fraîcheur</option>
                                <option>Sport à la fraich</option>
                                <option>Un point d’info</option>

                            {% elif categories=="Être au contact de l'eau" %}
                                <option>Être à l’ombre en nature</option>
                                <option selected>Être au contact de l'eau</option>
                                <option>Ressources solidaires</option>
                                <option>Se divertir en fraîcheur</option>
                                <option>Sport à la fraich</option>
                                <option>Un point d’info</option>

                            {% elif categories=="Ressources solidaires" %}
                                <option>Être à l’ombre en nature</option>
                                <option>Être au contact de l'eau</option>
                                <option selected>Ressources solidaires</option>
                                <option>Se divertir en fraîcheur</option>
                                <option>Sport à la fraich</option>
                                <option>Un point d’info</option>

                            {% elif categories=="Se divertir en fraîcheur" %}
                                <option>Être à l’ombre en nature</option>
                                <option>Être au contact de l'eau</option>
                                <option>Ressources solidaires</option>
                                <option selected>Se divertir en fraîcheur</option>
                                <option>Sport à la fraich</option>
                                <option>Un point d’info</option>

                            {% elif categories=="Sport à la fraich" %}
                                <option>Être à l’ombre en nature</option>
                                <option>Être au contact de l'eau</option>
                                <option>Ressources solidaires</option>
                                <option>Se divertir en fraîcheur</option>
                                <option selected>Sport à la fraich</option>
                                <option>Un point d’info</option>

                            {% elif categories=="Un point d’info" %}
                                <option>Être à l’ombre en nature</option>
                                <option>Être au contact de l'eau</option>
                                <option>Ressources solidaires</option>
                                <option>Se divertir en fraîcheur</option>
                                <option>Sport à la fraich</option>
                                <option selected>Un point d’info</option>
       
                            {% else %}
                                <option selected></option>
                                <option>Être à l’ombre en nature</option>
                                <option>Être au contact de l'eau</option>
                                <option>Ressources solidaires</option>
                                <option>Se divertir en fraîcheur</option>
                                <option>Sport à la fraich</option>
                                <option>Un point d’info</option>
                            {% endif %}

                            </select>
                        </span>
                </div>
                <!-- --------------------- Adresse 1 ---------------------- -->
                <div class="field">
                    <label class="label">adresse1</label>
                        <input
                        name="adresse1"
                        class="input"
                        value="{{adresse1}}"
                        type="text"
                        maxlength="50"
                        style="color: #3f3d3d;"
                        required>
                </div>
                <!-- --------------------- Adresse 2 --------------------- -->
                <div class="field">
                    <label class="label">adresse2</label>
                        <input
                        name="adresse2"
                        class="input"
                        value="{{adresse2}}"
                        type="text"
                        maxlength="50"
                        placeholder="Ex. Champ Clotury"
                        style="color: #3f3d3d;"
                        >
                </div>
                <!-- -------------------- Code postal --------------------- -->
                <div class="field">
                    <label class="label">Code postal</label>
                        <input
                        name="code_postal"
                        class="input"
                        value="{{code_postal}}"
                        type="text"
                        maxlength="50"
                        style="color: #3f3d3d;"
                        required>
                </div>
                <!-- ----------------------- City ------------------------ -->
                <div class="field">
                    <label class="label">City</label>
                        <input
                        name="city"
                        class="input"
                        value="{{city}}"
                        type="text"
                        maxlength="70"
                        style="color: #3f3d3d;"
                        required>
                </div>
                <!-- ----------------- Description Teaser ---------------- -->
                <div class="field">
                    <label class="label">Description Teaser</label>
                        <textarea
                        name="description_teaser"
                        class="textarea"
                        value="{{Description_Teaser}}"
                        maxlength="1000"
                        style="color: #3f3d3d;"
                        >
</textarea>
                </div>
                <!-- ---------- Upload url of an image ----------- -->
                <div class="field">
                    <label class="label">Images</label>
                        <input
                        name="images"
                        class="input"
                        value="{{Images}}"
                        type="text"
                        maxlength="50"
                        style="color: #3f3d3d;"
                        required>
                </div>
                <!-- -------------------------------------------------- -->
                <div class="field">
                    <label class="label">Publics</label>
                    {% if "senior" in publics%}
                        <label><input name="senior" type="checkbox" value ="Senior" checked>Senior&nbsp;&nbsp;&nbsp;&nbsp;</label>
                    {% else %}
                        <label><input name="senior" type="checkbox" value ="Senior">Senior&nbsp;&nbsp;&nbsp;&nbsp;</label>
                    {% endif %}
                    {% if "enfant" in publics%}
                        <label><input name="enfant" type="checkbox" value ="Enfant" checked>Enfant&nbsp;&nbsp;&nbsp;&nbsp;</label>
                    {% else %}
                        <label><input name="enfant" type="checkbox" value ="Enfant">Enfant&nbsp;&nbsp;&nbsp;&nbsp;</label>
                    {% endif %}
                    {% if "jeune" in publics%}
                        <label><input name="jeune" type="checkbox" value="Jeune" checked>Jeune&nbsp;&nbsp;&nbsp;&nbsp;</label>
                    {% else %}
                        <label><input name="jeune" type="checkbox" value="Jeune">Jeune&nbsp;&nbsp;&nbsp;&nbsp;</label>
                    {% endif %}
                    {% if "adulte" in publics%}
                        <label><input name="adult" type="checkbox" value="Adult" checked>Adult</label>
                    {% else %}
                        <label><input name="adult" type="checkbox" value="Adult">Adult</label>
                    {% endif %}
                    {% if "solidaire" in publics%}
                        <label><input name="adult" type="checkbox" value="Solidaire" checked>Solidaire</label>
                    {% else %}
                        <label><input name="adult" type="checkbox" value="Solidaire">Solidaire</label>
                    {% endif %}
                </div>
                <!-- --------------------------------------------------- -->
                <div class="field">
                    <label class="label">Categories</label>
                        <input
                        name="categories"
                        class="input"
                        value="{{categories}}"
                        type="text"
                        maxlength="50"
                        style="color: #3f3d3d;"
                        >
                </div>
                <!-- -------------------------------------------------- -->
                <div class="field">
                    <label class="label">Accessibilité</label>
                        <input
                        name="accessibilite"
                        class="input"
                        value="{{accessibilite}}"
                        type="text"
                        maxlength="50"
                        placeholder="Ex. Accessible en fauteuil roulant en autonomie"
                        style="color: #3f3d3d;"
                        required>
                </div>
                <!-- ------------------------------------------------ -->
                <div class="field">
                    <label class="label">Payant</label>
                        <span class="select">
                            <select name="payant" required>
                            {% if payant==True %}
                                <option selected>True</option>
                                <option>False</option>
                            {% elif payant==False %}
                                <option>True</option>
                                <option selected>False</option>
                            {% else %}
                                <option></option>
                                <option>True</option>
                                <option>False</option>
                            {% endif %}
                            </select>
                        </span>
                </div>
                <!-- -------------------------------------------------- -->
                <div class="field">
                    <label class="label">plus d'infos et horaires</label>
                        <input
                        name="plus_d_infos"
                        class="input"
                        value="{{plus_d_infos}}"
                        type="text"
                        maxlength="50"
                        placeholder="Ex. http://www.grenoble-tourisme.com"
                        style="color: #3f3d3d;"
                        >
                </div>
                <!-- ---------------------------------------------------- -->
                <div class="field">
                    <label class="label">Date début</label>
                        <input
                        name="date_debut"
                        class="input"
                        value="{{date_debut}}"
                        type="date"
                        style="color: #3f3d3d;"
                        >
                </div>
                <!-- ------------------------------------------------- -->
                <div class="field">
                    <label class="label">Date fin</label>
                        <input
                        name="date_fin"
                        class="input"
                        value="{{date_fin}}"
                        type="date"
                        style="color: #3f3d3d;"
                        >
                </div>
                <!-- ---------------------------------------------------- -->
              <div class="field is-grouped is-grouped-right">
                <div class="control">
                  <button class="button is-link">Add</button>
                </div>
              </div>
            </form>
          </div>
        </div>
      </div>
    </div>

<h3>{{errorMessage}}</h3>
{% endblock bootstrap_2 %}
